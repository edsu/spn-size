# %% [markdown]
# # SPN Sizes

# %%
import pandas

df = pandas.read_csv('save-page-now.csv', parse_dates=['date'])
df['gb'] = df['bytes'] / 1024 / 1024 / 1024
df
# Out:
#           date          bytes           gb
# 0   2020-02-22   924153122530   860.684665
# 1   2020-02-23  1965467061008  1830.483844
# 2   2020-02-24  1867608336805  1739.345805
# 3   2020-02-25  1779999943858  1657.754131
# 4   2020-02-26  1985847458884  1849.464568
# ..         ...            ...          ...
# 324 2021-01-11  3428936384081  3193.445861
# 325 2021-01-12  3285224623404  3059.603854
# 326 2021-01-13  2903855633975  2704.426305
# 327 2021-01-14  2653367080623  2471.140661
# 328 2021-01-15  1670336272292  1555.621878
#
# [329 rows x 3 columns]

# %%
from plotly import express as px

px.line(y=df.gb, x=df.date, labels={'x': 'Time', 'y': 'GB/day'}, title='SPN2 Daily Ingest')
# Out:
# <div>                            <div id="9eb39551-9f6c-4d48-a953-4906ea99f51a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9eb39551-9f6c-4d48-a953-4906ea99f51a")) {                    Plotly.newPlot(                        "9eb39551-9f6c-4d48-a953-4906ea99f51a",                        [{"hovertemplate": "Time=%{x}<br>GB/day=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2020-02-22T00:00:00", "2020-02-23T00:00:00", "2020-02-24T00:00:00", "2020-02-25T00:00:00", "2020-02-26T00:00:00", "2020-02-27T00:00:00", "2020-02-28T00:00:00", "2020-02-29T00:00:00", "2020-03-01T00:00:00", "2020-03-02T00:00:00", "2020-03-03T00:
# ...
