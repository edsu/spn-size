# %% [markdown]
# # SPN Sizes

# %%
import pandas

spn2 = pandas.read_csv('save-page-now.csv', parse_dates=['date'], index_col='date')
spn2['gb'] = spn2['bytes'] / 1024 / 1024 / 1024
spn2
# Out:
#                     bytes           gb
# date
# 2020-02-22   924153122530   860.684665
# 2020-02-23  1965467061008  1830.483844
# 2020-02-24  1867608336805  1739.345805
# 2020-02-25  1779999943858  1657.754131
# 2020-02-26  1985847458884  1849.464568
# ...                   ...          ...
# 2021-10-01  2685675343924  2501.230076
# 2021-10-02  2617723449374  2437.944943
# 2021-10-03  2699867865415  2514.447892
# 2021-10-04  2606664212853  2427.645226
# 2021-10-05    11776324259    10.967557
#
# [592 rows x 2 columns]

# %%
from plotly import express as px

px.line(y=spn2.gb, x=spn2.index, labels={'x': 'Time', 'y': 'GB/day'}, title='SPN2 Daily Ingest')
# Out:
# <div>                            <div id="1f7f952d-8b3a-4719-936b-5aafb44188ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f7f952d-8b3a-4719-936b-5aafb44188ae")) {                    Plotly.newPlot(                        "1f7f952d-8b3a-4719-936b-5aafb44188ae",                        [{"hovertemplate": "Time=%{x}<br>GB/day=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2020-02-22T00:00:00", "2020-02-23T00:00:00", "2020-02-24T00:00:00", "2020-02-25T00:00:00", "2020-02-26T00:00:00", "2020-02-27T00:00:00", "2020-02-28T00:00:00", "2020-02-29T00:00:00", "2020-03-01T00:00:00", "2020-03-02T00:00:00", "2020-03-03T00:
# ...

# %%
spn1 = pandas.read_csv('liveweb.csv', parse_dates=['date'], index_col='date')
spn1['gb'] = spn1['bytes'] / 1024 / 1024 / 1024
spn1
# Out:
#                     bytes           gb
# date
# 2011-03-27    10646200928     9.915047
# 2011-03-28    10707045468     9.971713
# 2011-03-29    21394690378    19.925358
# 2011-03-30    20976176471    19.535587
# 2011-03-31    20678636646    19.258481
# ...                   ...          ...
# 2018-10-30   332825274832   309.967692
# 2018-10-31   290559656060   270.604767
# 2018-11-01   380770727329   354.620374
# 2018-11-02  1151349419675  1072.277706
# 2018-11-03   762649283880   710.272495
#
# [2747 rows x 2 columns]

# %%
px.line(x=spn1.index, y=spn1.gb, labels={"x": "Time", "y": "GB/day"}, title="SPN1 Ingest Rate")
# Out:
# <div>                            <div id="56d562b0-c4c1-4c50-8bb2-a43173457cdd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56d562b0-c4c1-4c50-8bb2-a43173457cdd")) {                    Plotly.newPlot(                        "56d562b0-c4c1-4c50-8bb2-a43173457cdd",                        [{"hovertemplate": "Time=%{x}<br>GB/day=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2011-03-27T00:00:00", "2011-03-28T00:00:00", "2011-03-29T00:00:00", "2011-03-30T00:00:00", "2011-03-31T00:00:00", "2011-04-01T00:00:00", "2011-04-02T00:00:00", "2011-04-03T00:00:00", "2011-04-04T00:00:00", "2011-04-05T00:00:00", "2011-04-06T00:00:00", "2011-04-0
# ...

# %%
spn = pandas.DataFrame({"spn1": spn1.gb, "spn2": spn2.gb})
spn
# Out:
#                  spn1         spn2
# date
# 2011-03-27   9.915047          NaN
# 2011-03-28   9.971713          NaN
# 2011-03-29  19.925358          NaN
# 2011-03-30  19.535587          NaN
# 2011-03-31  19.258481          NaN
# ...               ...          ...
# 2021-10-01        NaN  2501.230076
# 2021-10-02        NaN  2437.944943
# 2021-10-03        NaN  2514.447892
# 2021-10-04        NaN  2427.645226
# 2021-10-05        NaN    10.967557
#
# [3339 rows x 2 columns]

# %%
px.line(spn)
# Out:
# <div>                            <div id="a1e0aec6-6ec7-4be0-bca9-8be6f5618846" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1e0aec6-6ec7-4be0-bca9-8be6f5618846")) {                    Plotly.newPlot(                        "a1e0aec6-6ec7-4be0-bca9-8be6f5618846",                        [{"hovertemplate": "variable=spn1<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "spn1", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "spn1", "showlegend": true, "type": "scattergl", "x": ["2011-03-27T00:00:00", "2011-03-28T00:00:00", "2011-03-29T00:00:00", "2011-03-30T00:00:00", "2011-03-31T00:00:00", "2011-04-01T00:00:00", "2011-04-02T00:00:00", "2011-04-03T00:00:00", "2011-04-04T00:00:00", "2011-04-05T00:00:00", "2011-04-0
# ...

# %%
spn_month = spn.resample('M').sum()
spn_month
# Out:
#                    spn1          spn2
# date
# 2011-03-31    78.606186      0.000000
# 2011-04-30   892.904426      0.000000
# 2011-05-31  1012.372902      0.000000
# 2011-06-30  1227.676154      0.000000
# 2011-07-31  1262.621201      0.000000
# ...                 ...           ...
# 2021-06-30     0.000000  75358.873103
# 2021-07-31     0.000000  68617.921263
# 2021-08-31     0.000000  74769.709743
# 2021-09-30     0.000000  67020.591178
# 2021-10-31     0.000000   9892.235692
#
# [128 rows x 2 columns]

# %%
fig = px.line(spn_month, title='SPN1 and SPN2 Ingest Rate', labels={'value': 'GB/month', 'date': 'Time'})
fig.update_layout(legend_title='Service Version')
fig
# Out:
# <div>                            <div id="d548160f-7823-420e-a734-016453d135c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d548160f-7823-420e-a734-016453d135c7")) {                    Plotly.newPlot(                        "d548160f-7823-420e-a734-016453d135c7",                        [{"hovertemplate": "variable=spn1<br>Time=%{x}<br>GB/month=%{y}<extra></extra>", "legendgroup": "spn1", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "spn1", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2011-03-31T00:00:00", "2011-04-30T00:00:00", "2011-05-31T00:00:00", "2011-06-30T00:00:00", "2011-07-31T00:00:00", "2011-08-31T00:00:00", "2011-09-30T00:00:00", "2011-10-31T00:00:00", "2011-11-30T00:00:00", "2011-12-31T
# ...
